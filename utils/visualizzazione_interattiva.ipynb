# %%
import os
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display
import plotly.graph_objects as go
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def visualize_nifti_all_frames_in_a_4d_file(filepath):

    img = nib.load(filepath)
    data = img.get_fdata()

    if len(data.shape) != 4:
        print(f"Il file {os.path.basename(filepath)} non è 4D.")
        return

    slice_idx = data.shape[2] // 2  # Slice centrale
    num_frames = data.shape[3]

    for frame_idx in range(num_frames):
        plt.imshow(data[:, :, slice_idx, frame_idx].T, cmap='gray', origin='lower')
        plt.title(f"Frame {frame_idx} - Slice {slice_idx} di {os.path.basename(filepath)}")
        plt.axis("off")
        plt.show()

# %%
path='/content/drive/MyDrive/patient001_4d.nii.gz'
visualize_nifti_all_frames_in_a_4d_file(path)

# %%
def visualize_nifti_slices(filepath):
    """Visualizza le slice assiali di un file NIfTI."""
    img = nib.load(filepath)
    data = img.get_fdata()

    if len(data.shape) < 3:
        print(f"Formato non supportato: {os.path.basename(filepath)}")
        return

    max_slice = data.shape[2] - 1

    def show_slice(slice_idx):
        plt.imshow(data[:, :, slice_idx].T, cmap='gray', origin='lower')
        plt.title(f"Slice {slice_idx} di {os.path.basename(filepath)}")
        plt.axis("off")
        plt.show()

    widgets.interact(show_slice, slice_idx=widgets.IntSlider(min=0, max=max_slice, step=1, value=max_slice // 2))

# %%
path = '/content/drive/MyDrive/patient001_frame01.nii.gz'
visualize_nifti_slices(path)
# Out:
# interactive(children=(IntSlider(value=4, description='slice_idx', max=9), Output()), _dom_classes=('widget-int…

# %%
path = '/content/drive/MyDrive/patient001_frame01_gt.nii.gz'
visualize_nifti_slices(path)
# Out:
# interactive(children=(IntSlider(value=4, description='slice_idx', max=9), Output()), _dom_classes=('widget-int…

# %%
path = '/content/drive/MyDrive/fdt_paths.nii'
visualize_nifti_slices(path)
# Out:
# interactive(children=(IntSlider(value=45, description='slice_idx', max=90), Output()), _dom_classes=('widget-i…

# %%
path = '/content/drive/MyDrive/patient001_frame01_gt_preprocessed.nii.gz'
visualize_nifti_slices(path)
# Out:
# interactive(children=(IntSlider(value=4, description='slice_idx', max=9), Output()), _dom_classes=('widget-int…

# %%
path = '/content/drive/MyDrive/patient001_frame12_gt_preprocessed.nii.gz'
visualize_nifti_slices(path)
# Out:
# interactive(children=(IntSlider(value=4, description='slice_idx', max=9), Output()), _dom_classes=('widget-int…

# %%
path = '/content/drive/MyDrive/patient001_frame12_preprocessed.nii.gz'
visualize_nifti_slices(path)
# Out:
# interactive(children=(IntSlider(value=4, description='slice_idx', max=9), Output()), _dom_classes=('widget-int…
